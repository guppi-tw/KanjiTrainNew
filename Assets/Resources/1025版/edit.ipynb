# %%
import pandas as pd
import os

# %%
KanjiData = pd.read_excel("中学相当漢字問題データ.xlsx",index_col=0)
KanjiData.head(3)
# Out:
#    kanji    example
# id
# 1      窮  生活に困キュウする
# 2      券     食ケンを買う
# 3      凍    寒さにコゴえる

# %%
folderfile = os.listdir(r"D:\Unity\KanjiTrain2\Assets\Resources\1025版")
#print(folderfile)

for file in folderfile:
    if ".jpg.jpg" in file:
        new_name = file.replace(".jpg.jpg",".jpg")
        os.rename(file,new_name)
        print(new_name)
# Out:
# 31_騰_0.jpg
# 31_騰_1.jpg
# 31_騰_2.jpg
# 31_騰_3.jpg
# 32_蹴_0.jpg
# 32_蹴_1.jpg
# 32_蹴_2.jpg
# 32_蹴_3.jpg
# 33_薄_0.jpg
# 33_薄_1.jpg
# 33_薄_2.jpg
# 33_薄_3.jpg
# 34_藤_0.jpg
# 34_藤_1.jpg
# 34_藤_2.jpg
# 34_藤_3.jpg
# 35_覇_0.jpg
# 35_覇_1.jpg
# 35_覇_2.jpg
# 35_覇_3.jpg
# 36_懸_0.jpg
# 36_懸_1.jpg
# 36_懸_2.jpg
# 36_懸_3.jpg
# 37_刹_0.jpg
# 37_刹_1.jpg
# 37_刹_2.jpg
# 37_刹_3.jpg
# 38_襲_0.jpg
# 38_襲_1.jpg
# 38_襲_2.jpg
# 38_襲_3.jpg
# 39_旺_0.jpg
# 39_旺_1.jpg
# 39_旺_2.jpg
# 39_旺_3.jpg
# 40_雌_0.jpg
# 40_雌_1.jpg
# 40_雌_2.jpg
# 40_雌_3.jpg
# 41_譲_0.jpg
# 41_譲_1.jpg
# 41_譲_2.jpg
# 41_譲_3.jpg
# 42_籍_0.jpg
# 42_籍_1.jpg
# 42_籍_2.jpg
# 42_籍_3.jpg
# 43_癒_0.jpg
# 43_癒_1.jpg
# 43_癒_2.jpg
# 43_癒_3.jpg
# 44_微_0.jpg
# 44_微_1.jpg
# 44_微_2.jpg
# 44_微_3.jpg
# 45_徴_0.jpg
# 45_徴_1.jpg
# 45_徴_2.jpg
# 45_徴_3.jpg
# 46_拘_0.jpg
# 46_拘_1.jpg
# 46_拘_2.jpg
# 46_拘_3.jpg
# 47_祉_0.jpg
# 47_祉_1.jpg
# 47_祉_2.jpg
# 47_祉_3.jpg
# 48_淑_0.jpg
# 48_淑_1.jpg
# 48_淑_2.jpg
# 48_淑_3.jpg
# 49_擬_0.jpg
# 49_擬_1.jpg
# 49_擬_2.jpg
# 49_擬_3.jpg
# ...
